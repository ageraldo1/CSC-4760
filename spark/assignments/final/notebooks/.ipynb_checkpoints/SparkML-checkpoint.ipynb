# %% [markdown]
# ## Spark Machine Learning
# ### Linear Regression
# ____

# %% [markdown]
# #### Dependencies
# _____

# %%
from pyspark.sql import SparkSession
from pyspark.ml.regression import LinearRegression, LinearRegressionModel
from pyspark.ml.linalg import Vectors
from pyspark.ml.feature import VectorAssembler

import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

sns.set(style="whitegrid")

# %% [markdown]
# #### Spark Session
# ___

# %%
spark = SparkSession.builder.appName('lr').getOrCreate()

# %% [markdown]
# #### Load Data
# ____

# %%
data = spark.read.csv('../resources/Ecommerce_Customers.csv',inferSchema=True, header=True)

data.show(n=5)
# Out:
# +------------------+-----------+---------------+--------------------+-------------------+
# |Avg Session Length|Time on App|Time on Website|Length of Membership|Yearly Amount Spent|
# +------------------+-----------+---------------+--------------------+-------------------+
# |       34.49726773|12.65565115|    39.57766802|         4.082620633|         587.951054|
# |       31.92627203|11.10946073|    37.26895887|         2.664034182|        392.2049334|
# |       33.00091476|11.33027806|    37.11059744|         4.104543202|        487.5475049|
# |       34.30555663|13.71751367|    36.72128268|         3.120178783|         581.852344|
# |       33.33067252|12.79518855|     37.5366533|         4.446308318|         599.406092|
# +------------------+-----------+---------------+--------------------+-------------------+
# only showing top 5 rows

# %% [markdown]
# #### Data Analysis
# _____

# %%
sns.pairplot(data.toPandas())

plt.tight_layout()

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(16,8))
sns.heatmap(data.toPandas().corr(), annot=True, cmap='PuBu',ax=axes)

plt.tight_layout()

# %% [markdown]
# #### Create Features Vector
# ____

# %%
assembler = VectorAssembler(inputCols=['Avg Session Length', 'Time on App', 'Time on Website', 'Length of Membership'], outputCol='features')
output = assembler.transform(data)

output.printSchema()
# Out:
# root
#  |-- Avg Session Length: double (nullable = true)
#  |-- Time on App: double (nullable = true)
#  |-- Time on Website: double (nullable = true)
#  |-- Length of Membership: double (nullable = true)
#  |-- Yearly Amount Spent: double (nullable = true)
#  |-- features: vector (nullable = true)

# %%
master = output.select(['features', 'Yearly Amount Spent'])
master.show(n=5)
# Out:
# +--------------------+-------------------+
# |            features|Yearly Amount Spent|
# +--------------------+-------------------+
# |[34.49726773,12.6...|         587.951054|
# |[31.92627203,11.1...|        392.2049334|
# |[33.00091476,11.3...|        487.5475049|
# |[34.30555663,13.7...|         581.852344|
# |[33.33067252,12.7...|         599.406092|
# +--------------------+-------------------+
# only showing top 5 rows

# %% [markdown]
# #### Split Training & Test Data
# ___

# %%
train, test = master.randomSplit([0.7, 0.3])

print (f'Total of records for TRAIN : {train.count()}')
print (f'Total of records for TEST : {test.count()}')
# Out:
# Total of records for TRAIN : 347
# Total of records for TEST : 153

# %% [markdown]
# #### Create Linear Regression Model
# ___

# %%
model = LinearRegression(featuresCol='features', labelCol='Yearly Amount Spent', predictionCol='predictions').fit(train)

# %% [markdown]
# #### Model Evaluation
# _____

# %%
results = model.evaluate(test)

print(f'Root Mean Square : {results.rootMeanSquaredError} - R2 : {results.r2}')
# Out:
# Root Mean Square : 10.978249900061723 - R2 : 0.9800905606658823

# %% [markdown]
# #### Deploy Model
# _____

# %%
model.save('../models/lr')
